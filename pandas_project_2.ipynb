# %% [markdown]
# Project 2-- Reading file and applying filter and sorting in it

# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\om'

# %%
os.chdir("D://Business analytics//Excel class//Python")
os.getcwd()
# Out:
# 'D:\\Business analytics\\Excel class\\Python'

# %%
file = pd.read_csv("employees.csv")
file
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55  08-04-2016    $1,41,604
# ...

# %%
file.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
#through this we are able to know about the null values present in our data
null_values = file.isnull().any(axis=1)
null_data = file[null_values]
null_data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# 5    E00644     Joshua Gupta    Account Representative       Sales
# ..      ...              ...                       ...         ...
# 994  E01148   Scarlett Kumar           Systems Analyst          IT
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#            Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 1          Manufacturing    Male      Asian   59  29-11-1997      $99,975
# ...

# %%
#we find null values in the end column exit date...no replacing it with some other values
values = {"Exit Date":"Working"}
file = file.fillna(value = values)
file
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55  08-04-2016    $1,41,604
# ...

# %%
#filtering --- normal filter through giving conditions
#filtering the age column here for the age > 40 only data show
filtered_data = file[file["Age"] > 40]
filtered_data
# Out:
#        EEID          Full Name               Job Title       Department  \
# 0    E02387        Emily Davis              Sr. Manger               IT
# 1    E04105      Theodore Dinh     Technical Architect               IT
# 2    E02572       Luna Sanders                Director          Finance
# 4    E01639          Austin Vo             Sr. Analyst          Finance
# 5    E00644       Joshua Gupta  Account Representative            Sales
# ..      ...                ...                     ...              ...
# 991  E03430        Leo Herrera    Sr. Business Partner  Human Resources
# 993  E04762  Audrey Richardson                Director               IT
# 994  E01148     Scarlett Kumar         Systems Analyst               IT
# 996  E01909       Lillian Khan                 Analyst          Finance
# 999  E03545        Sofia Cheng          Vice President       Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# ...

# %%
#sorting--- making in an order to represent the data
#target-- to sort the data on the basis of revenue in ascending order
filtered_data = filtered_data.sort_values(by = "Annual Salary",ascending = False)
filtered_data
# Out:
#        EEID           Full Name                       Job Title  \
# 1    E04105       Theodore Dinh             Technical Architect
# 537  E04756            Aiden Le  Cloud Infrastructure Architect
# 472  E04155     Dylan Dominguez                     Sr. Analyst
# 419  E01807         Matthew Lim                     Sr. Analyst
# 528  E01870        Easton Moore        Computer Systems Manager
# ..      ...                 ...                             ...
# 977  E00836         Wesley King                         Manager
# 938  E01722         Asher Huynh                         Manager
# 711  E03471      Julia Sandoval                         Manager
# 815  E01508  Penelope Rodriguez             Engineering Manager
# 179  E03446         Julian Ross                         Manager
#
#           Department           Business Unit  Gender  Ethnicity  Age  \
# 1                 IT           Manufacturing    Male      Asian   59
# ...

# %%
#target-- now we have to find the mean of annual salary for particular department
filtered_data = filtered_data.rename(columns = {"EEID":"Employee ID"})
filtered_data
# Out:
#     Employee ID           Full Name                       Job Title  \
# 1        E04105       Theodore Dinh             Technical Architect
# 537      E04756            Aiden Le  Cloud Infrastructure Architect
# 472      E04155     Dylan Dominguez                     Sr. Analyst
# 419      E01807         Matthew Lim                     Sr. Analyst
# 528      E01870        Easton Moore        Computer Systems Manager
# ..          ...                 ...                             ...
# 977      E00836         Wesley King                         Manager
# 938      E01722         Asher Huynh                         Manager
# 711      E03471      Julia Sandoval                         Manager
# 815      E01508  Penelope Rodriguez             Engineering Manager
# 179      E03446         Julian Ross                         Manager
#
#           Department           Business Unit  Gender  Ethnicity  Age  \
# 1                 IT           Manufacturing    Male      Asian   59
# ...

# %%
data_1 = filtered_data[["Department","Annual Salary"]]
data_1 = data_1.reset_index(drop = True)
#conversion command for currency values into normal integer values
data_1["Annual Salary"] = data_1["Annual Salary"].replace("[\$,]","",regex = True).astype(int)
data_1
# Out:
#           Department  Annual Salary
# 0                 IT          99975
# 1                 IT          99774
# 2          Marketing          99697
# 3              Sales          99624
# 4                 IT          99557
# ..               ...            ...
# 611       Accounting         101577
# 612               IT         101288
# 613  Human Resources         101143
# 614      Engineering         100810
# 615        Marketing         100099
#
# [616 rows x 2 columns]

# %%
data_1 = data_1.groupby("Department").mean()
data_1 = data_1.reset_index()
data_1
data_1["Annual Salary"] = data_1["Annual Salary"].astype(int)
data_1
# Out:
#         Department  Annual Salary
# 0       Accounting         122196
# 1      Engineering         108656
# 2          Finance         119484
# 3  Human Resources         115981
# 4               IT          97812
# 5        Marketing         129741
# 6            Sales         116863

# %%
#program -- to finding which department which annual salary is highest and lowest
salary = []
department = []
for x in data_1["Department"]:
        department.append(x)
for i in data_1["Annual Salary"]:
    salary.append(i)
    
print(salary)
print(department)
#highest value among all the values present in the list
highest_value = max(salary)
#lowest value among all the values present in the list
lowest_value = min(salary)
print(highest_value)
print(lowest_value)
highest_index = salary.index(highest_value)
lowest_index = salary.index(lowest_value)
highest_dept = department[highest_index]
lowest_dept = department[lowest_index]
print("The Highest Annual Salary average among all department is {} with value of {}".format(highest_dept,highest_value))
print("The lowest Annual Salary average among all the department is {} with value of {}".format(lowest_dept,lowest_value))
# Out:
# [122196, 108656, 119484, 115981, 97812, 129741, 116863]
# ['Accounting', 'Engineering', 'Finance', 'Human Resources', 'IT', 'Marketing', 'Sales']
# 129741
# 97812
# The Highest Annual Salary average among all department is Marketing with value of 129741
# The lowest Annual Salary average among all the department is IT with value of 97812
